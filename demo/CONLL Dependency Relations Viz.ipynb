# %%
from stanza.models.common.constant import is_right_to_left
import spacy
from spacy import displacy
from spacy.tokens import Doc
from stanza.utils import conll
from stanza.utils.visualization import document_to_viz as viz


def conll_to_visual(conll_file, pipeline, sent_count=10, display_all=False):
    """
    Takes in a conll file and visualizes it by converting the conll file to a Stanza Document object
    and visualizing it with the visualize_doc method. Input should be a proper conll file. The pipeline
    for the conll file to be processed in must be provided as well. Optionally, the sent_count argument
    can be tweaked to display a different amount of sentences. To display all of the sentences in a
    conll file, the display_all argument can optionally be set to True. BEWARE: setting this argument
    for a large conll file may result in too many renderings, resulting in a crash.
    """
    # convert conll file to doc
    doc = conll.CoNLL.conll2doc(conll_file)

    if display_all:
        print("ENTERED HERE")
        viz.visualize_doc(conll.CoNLL.conll2doc(conll_file), pipeline)
    else:  # visualize a given number of sentences
        print("ENTERED HERE")
        visualization_options = {"compact": True, "bg": "#09a3d5", "color": "white", "distance": 100,
                                 "font": "Source Sans Pro", "offset_x": 30,
                                 "arrow_spacing": 20}  # see spaCy visualization settings doc for more options
        nlp = spacy.blank("en")
        sentences_to_visualize, rtl, num_sentences = [], is_right_to_left(pipeline), len(doc.sentences)

        for i in range(sent_count):
            if i >= num_sentences:  # case where there are less sentences than amount requested
                break
            sentence = doc.sentences[i]
            words, lemmas, heads, deps, tags = [], [], [], [], []
            sentence_words = sentence.words
            if rtl:
                sentence_words = reversed(sentence.words)
                sent_len = len(sentence.words)
            for word in sentence_words:
                words.append(word.text)
                lemmas.append(word.lemma)
                deps.append(word.deprel)
                tags.append(word.upos)
                if rtl and word.head == 0:  # word heads are off-by-1 in spaCy doc inits compared to Stanza
                    heads.append(sent_len - word.id)
                elif rtl and word.head != 0:
                    heads.append(sent_len - word.head)
                elif not rtl and word.head == 0:
                    heads.append(word.id - 1)
                elif not rtl and word.head != 0:
                    heads.append(word.head - 1)

            document_result = Doc(nlp.vocab, words=words, lemmas=lemmas, heads=heads, deps=deps, pos=tags)
            sentences_to_visualize.append(document_result)

        print(sentences_to_visualize)
        for line in sentences_to_visualize:  # render all sentences through displaCy
            displacy.render(line, style="dep", options=visualization_options)


def main():

    en_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\en_test.conllu.txt"
    jp_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\japanese_test.conllu.txt"
    ar_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\arabic_test.conllu.txt"
    conll_to_visual(en_file, "en", sent_count=2)
    conll_to_visual(en_file, "en", sent_count=10)
    conll_to_visual(en_file, "en", display_all=True)
    conll_to_visual(jp_file, "ja")
    conll_to_visual(ar_file, "ar")
    return


if __name__ == "__main__":
    main()
# Out:
# ENTERED HERE
# [What if Google Morphed Into GoogleOS ? , What if Google expanded on its search - engine ( and now e-mail ) wares into a full - fledged operating system ? ]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="af06929c69cc46319ed134789c2d6893-0" class="displacy" width="630" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af06929c69cc46319ed134789c2d6893-0-0" stroke-width="2px" d="M150,152.0 150,118.66666666666666 325.0,118.66666666666666 325.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af06929c69cc46319ed134789c2d6893-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,154.0 L146,146.0 154,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af06929c69cc46319ed134789c2d6893-0-1" stroke-width="2px" d="M250,152.0 250,135.33333333333334 320.0,135.33333333333334 320.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af06929c69cc46319ed134789c2d6893-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,154.0 L246,146.0 254,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af06929c69cc46319ed134789c2d6893-0-2" stroke-width="2px" d="M50,152.0 50,102.0 330.0,102.0 330.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af06929c69cc46319ed134789c2d6893-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M330.0,154.0 L334.0,146.0 326.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af06929c69cc46319ed134789c2d6893-0-3" stroke-width="2px" d="M450,152.0 450,135.33333333333334 520.0,135.33333333333334 520.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af06929c69cc46319ed134789c2d6893-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,154.0 L446,146.0 454,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af06929c69cc46319ed134789c2d6893-0-4" stroke-width="2px" d="M350,152.0 350,118.66666666666666 525.0,118.66666666666666 525.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af06929c69cc46319ed134789c2d6893-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,154.0 L529.0,146.0 521.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a35bef6ae6740e98c1c0f5b218014a8-0" class="displacy" width="1830" height="537.0" direction="ltr" style="max-width: none; height: 537.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">engine (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">e-mail )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">wares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1230">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1430">full -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1430">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1530">fledged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1630">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">system ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-0" stroke-width="2px" d="M150,402.0 150,368.6666666666667 300.0,368.6666666666667 300.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,404.0 L146,396.0 154,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-1" stroke-width="2px" d="M250,402.0 250,385.3333333333333 295.0,385.3333333333333 295.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,404.0 L246,396.0 254,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-2" stroke-width="2px" d="M50,402.0 50,352.0 305.0,352.0 305.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M305.0,404.0 L309.0,396.0 301.0,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-3" stroke-width="2px" d="M450,402.0 450,302.0 1120.0,302.0 1120.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,404.0 L446,396.0 454,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-4" stroke-width="2px" d="M550,402.0 550,318.6666666666667 1115.0,318.6666666666667 1115.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,404.0 L546,396.0 554,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0a35bef6ae6740e98c1c0f5b218014a8-0-5" stroke-width="2px" d="M650,402.0 650,385.3333333333333 695.0,385.3333333333333 695.0,402.0" fill="none" stroke
# ENTERED HERE
# [What if Google Morphed Into GoogleOS ? , What if Google expanded on its search - engine ( and now e-mail ) wares into a full - fledged operating system ? , [ via Microsoft Watch from Mary Jo Foley ] , ( And , by the way , is anybody else just a little nostalgic for the days when that was a good thing ? ) ]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c43e15c118124f45ad648a97a14c9d8c-0" class="displacy" width="630" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c43e15c118124f45ad648a97a14c9d8c-0-0" stroke-width="2px" d="M150,152.0 150,118.66666666666666 325.0,118.66666666666666 325.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c43e15c118124f45ad648a97a14c9d8c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,154.0 L146,146.0 154,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c43e15c118124f45ad648a97a14c9d8c-0-1" stroke-width="2px" d="M250,152.0 250,135.33333333333334 320.0,135.33333333333334 320.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c43e15c118124f45ad648a97a14c9d8c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,154.0 L246,146.0 254,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c43e15c118124f45ad648a97a14c9d8c-0-2" stroke-width="2px" d="M50,152.0 50,102.0 330.0,102.0 330.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c43e15c118124f45ad648a97a14c9d8c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M330.0,154.0 L334.0,146.0 326.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c43e15c118124f45ad648a97a14c9d8c-0-3" stroke-width="2px" d="M450,152.0 450,135.33333333333334 520.0,135.33333333333334 520.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c43e15c118124f45ad648a97a14c9d8c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,154.0 L446,146.0 454,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c43e15c118124f45ad648a97a14c9d8c-0-4" stroke-width="2px" d="M350,152.0 350,118.66666666666666 525.0,118.66666666666666 525.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c43e15c118124f45ad648a97a14c9d8c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,154.0 L529.0,146.0 521.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e7fe10d3776442b0821a31127a328cfb-0" class="displacy" width="1830" height="537.0" direction="ltr" style="max-width: none; height: 537.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">engine (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">e-mail )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">wares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1230">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1430">full -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1430">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1530">fledged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1630">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">system ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-0" stroke-width="2px" d="M150,402.0 150,368.6666666666667 300.0,368.6666666666667 300.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e7fe10d3776442b0821a31127a328cfb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,404.0 L146,396.0 154,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-1" stroke-width="2px" d="M250,402.0 250,385.3333333333333 295.0,385.3333333333333 295.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e7fe10d3776442b0821a31127a328cfb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,404.0 L246,396.0 254,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-2" stroke-width="2px" d="M50,402.0 50,352.0 305.0,352.0 305.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e7fe10d3776442b0821a31127a328cfb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M305.0,404.0 L309.0,396.0 301.0,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-3" stroke-width="2px" d="M450,402.0 450,302.0 1120.0,302.0 1120.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e7fe10d3776442b0821a31127a328cfb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,404.0 L446,396.0 454,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-4" stroke-width="2px" d="M550,402.0 550,318.6666666666667 1115.0,318.6666666666667 1115.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e7fe10d3776442b0821a31127a328cfb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,404.0 L546,396.0 554,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e7fe10d3776442b0821a31127a328cfb-0-5" stroke-width="2px" d="M650,402.0 650,385.3333333333333 695.0,385.3333333333333 695.0,402.0" fill="none" stroke
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cf805048e66d40d6863ba4f47023420c-0" class="displacy" width="830" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">via</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Microsoft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Watch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Mary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">Jo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">Foley ]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-0" stroke-width="2px" d="M50,152.0 50,102.0 330.0,102.0 330.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M50,154.0 L46,146.0 54,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-1" stroke-width="2px" d="M150,152.0 150,118.66666666666666 325.0,118.66666666666666 325.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,154.0 L146,146.0 154,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-2" stroke-width="2px" d="M250,152.0 250,135.33333333333334 320.0,135.33333333333334 320.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,154.0 L246,146.0 254,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-3" stroke-width="2px" d="M450,152.0 450,135.33333333333334 520.0,135.33333333333334 520.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,154.0 L446,146.0 454,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-4" stroke-width="2px" d="M350,152.0 350,118.66666666666666 525.0,118.66666666666666 525.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,154.0 L529.0,146.0 521.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-5" stroke-width="2px" d="M550,152.0 550,135.33333333333334 620.0,135.33333333333334 620.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620.0,154.0 L624.0,146.0 616.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf805048e66d40d6863ba4f47023420c-0-6" stroke-width="2px" d="M550,152.0 550,118.66666666666666 725.0,118.66666666666666 725.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf805048e66d40d6863ba4f47023420c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M725.0,154.0 L729.0,146.0 721.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a5986f8cc76b4f71a074fc7a2fd6b69b-0" class="displacy" width="2130" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">And ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">way ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">anybody</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">else</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">little</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">nostalgic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1230">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1430">days</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1530">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1530">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1630">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1630">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1830">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1830">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1930">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">thing ? )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-0" stroke-width="2px" d="M50,352.0 50,235.33333333333331 1130.0,235.33333333333331 1130.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M50,354.0 L46,346.0 54,346.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-1" stroke-width="2px" d="M150,352.0 150,252.0 1125.0,252.0 1125.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,354.0 L146,346.0 154,346.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-2" stroke-width="2px" d="M250,352.0 250,318.6666666666667 405.0,318.6666666666667 405.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,354.0 L246,346.0 254,346.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-3" stroke-width="2px" d="M350,352.0 350,335.3333333333333 400.0,335.3333333333333 400.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a5986f8cc76b4f71a074fc7a2fd6b69b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,354.0 L346,346.0 354,346.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a5986f8cc76b4f71a074fc7a2fd6
# ENTERED HERE
# [What if Google Morphed Into GoogleOS ? , What if Google expanded on its search - engine ( and now e-mail ) wares into a full - fledged operating system ? , [ via Microsoft Watch from Mary Jo Foley ] , ( And , by the way , is anybody else just a little nostalgic for the days when that was a good thing ? ) ]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3bf8d7361d3e4c3a8a2eab07678cd9f1-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-0" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-1" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-2" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,124.0 L294.0,116.0 286.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-3" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,124.0 L378,116.0 386,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-4" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3bf8d7361d3e4c3a8a2eab07678cd9f1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,124.0 L451.0,116.0 443.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bcdfeba96eac42caa75a969310436bb5-0" class="displacy" width="1490" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">الداخلية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">وزير</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">منصب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">السياسي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">الامن</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">شعبة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">رئيس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">كنعان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">غازي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">اللواء</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">تسلم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1230">فيما</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1230">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">الحسن</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1430">أحمد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1530">ل</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1630">خلفا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">الاعلام</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1830">وزير</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1830">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1930">منصب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">تسلم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">التوجهات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2230">الليبرالي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2230">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">الحاكم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2530">الحزب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2630">صحيفة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2630">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2730">تحرير</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2830">رئيس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2830">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">الله</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3030">دخل</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3030">
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="810314d05609463cb5434b9c1ece629f-0" class="displacy" width="1730" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="30">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">الاقتصاد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">الداخلية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="430">وزارتا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">ها</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="630">بين</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="630">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">حقائب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">ثماني</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">شمل</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">التعديل</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">ان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1230">السورية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1230">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">الانباء</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1430">وكالة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1530">ذكرت</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1630">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1630">CCONJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-0" stroke-width="2px" d="M50,202.0 50,135.33333333333331 1630.0,135.33333333333331 1630.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M50,204.0 L46,196.0 54,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-1" stroke-width="2px" d="M150,202.0 150,168.66666666666666 320.0,168.66666666666666 320.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,204.0 L146,196.0 154,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-2" stroke-width="2px" d="M150,202.0 150,185.33333333333334 215.0,185.33333333333334 215.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,204.0 L219.0,196.0 211.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-3" stroke-width="2px" d="M350,202.0 350,185.33333333333334 415.0,185.33333333333334 415.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,204.0 L346,196.0 354,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-4" stroke-width="2px" d="M450,202.0 450,185.33333333333334 515.0,185.33333333333334 515.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450,204.0 L446,196.0 454,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-810314d05609463cb5434b9c1ece629f-0-5" stroke-width="2px" d="M550,202.0 550,168.66666666666666 720.0,168.66666666666666 720.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-810314d05609463cb5434b9c1ece629f-0-5" class="displacy-label" startOffset="50%" side="left
