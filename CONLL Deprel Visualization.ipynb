# %%
from stanza.utils import conll
from stanza.utils.visualization import document_to_viz as viz


def conll_to_visual(conll_file, pipeline):
    """
    Takes in a conll file and visualizes it by converting the conll file to a Stanza Document object
    and visualizing it with the visualize_doc method. Input should be a proper conll file. The pipeline
    for the conll file to be processed in must be provided as well.
    """
    viz.visualize_doc(conll.CoNLL.conll2doc(conll_file), pipeline)


def main():
    file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\en_ewt-ud-test.conllu.txt"
    conll_to_visual(file, "en")
    return 0

main()
# Out:
# 2022-06-30 22:21:10 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# PRINTING ARABIC DOCUMENTS
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-06-30 22:21:12 INFO: Loading these models for language: ar (Arabic):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | padt    |
# | mwt       | padt    |
# | pos       | padt    |
# | lemma     | padt    |
# | depparse  | padt    |
# | ner       | aqmar   |
# =======================
#
# 2022-06-30 22:21:12 INFO: Use device: cpu
# 2022-06-30 22:21:12 INFO: Loading: tokenize
# 2022-06-30 22:21:12 INFO: Loading: mwt
# 2022-06-30 22:21:12 INFO: Loading: pos
# 2022-06-30 22:21:12 INFO: Loading: lemma
# 2022-06-30 22:21:12 INFO: Loading: depparse
# 2022-06-30 22:21:12 INFO: Loading: ner
# 2022-06-30 22:21:13 INFO: Done loading processors!
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ca250b32f3694e39ad429d4be59a1f12-0" class="displacy" width="930" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">الالمانية &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">ليوبارد &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">دبابة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">تصنيع</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">رخصة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">على</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">اميركية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">شركة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">حصول</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">ترفض</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">برلين</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-0" stroke-width="2px" d="M62,82.0 62,55.33333333333333 210.0,55.33333333333333 210.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,84.0 L58,76.0 66,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-1" stroke-width="2px" d="M142,82.0 142,68.66666666666667 207.0,68.66666666666667 207.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,84.0 L138,76.0 146,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-2" stroke-width="2px" d="M222,82.0 222,68.66666666666667 287.0,68.66666666666667 287.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,84.0 L218,76.0 226,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-3" stroke-width="2px" d="M302,82.0 302,68.66666666666667 367.0,68.66666666666667 367.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,84.0 L298,76.0 306,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-4" stroke-width="2px" d="M382,82.0 382,55.33333333333333 690.0,55.33333333333333 690.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,84.0 L378,76.0 386,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-5" stroke-width="2px" d="M382,82.0 382,68.66666666666667 447.0,68.66666666666667 447.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,84.0 L451.0,76.0 443.0,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-6" stroke-width="2px" d="M542,82.0 542,68.66666666666667 607.0,68.66666666666667 607.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M542,84.0 L538,76.0 546,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-7" stroke-width="2px" d="M622,82.0 622,68.66666666666667 687.0,68.66666666666667 687.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca250b32f3694e39ad429d4be59a1f12-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M622,84.0 L618,76.0 626,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca250b32f3694e39ad429d4be59a1f12-0-8" stroke-width="2px" d="M702,82.0 702,68.66666666666667
# 2022-06-30 22:21:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-06-30 22:21:15 INFO: Loading these models for language: ar (Arabic):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | padt    |
# | mwt       | padt    |
# | pos       | padt    |
# | lemma     | padt    |
# | depparse  | padt    |
# | ner       | aqmar   |
# =======================
#
# 2022-06-30 22:21:15 INFO: Use device: cpu
# 2022-06-30 22:21:15 INFO: Loading: tokenize
# 2022-06-30 22:21:15 INFO: Loading: mwt
# 2022-06-30 22:21:16 INFO: Loading: pos
# 2022-06-30 22:21:16 INFO: Loading: lemma
# 2022-06-30 22:21:16 INFO: Loading: depparse
# 2022-06-30 22:21:16 INFO: Loading: ner
# 2022-06-30 22:21:17 INFO: Done loading processors!
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="96db6f7c26d64a3abafc7b68ef334b3f-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">؟</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">ك</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">مساعدة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">إمكاني</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">ب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">هل</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PART</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-0" stroke-width="2px" d="M62,122.0 62,82.0 450.0,82.0 450.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,124.0 L58,116.0 66,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-1" stroke-width="2px" d="M142,122.0 142,108.66666666666667 204.0,108.66666666666667 204.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-2" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-3" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,124.0 L298,116.0 306,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-4" stroke-width="2px" d="M302,122.0 302,108.66666666666667 364.0,108.66666666666667 364.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-96db6f7c26d64a3abafc7b68ef334b3f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M364.0,124.0 L368.0,116.0 360.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>
# 2022-06-30 22:21:18 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-06-30 22:21:19 INFO: Loading these models for language: ar (Arabic):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | padt    |
# | mwt       | padt    |
# | pos       | padt    |
# | lemma     | padt    |
# | depparse  | padt    |
# | ner       | aqmar   |
# =======================
#
# 2022-06-30 22:21:19 INFO: Use device: cpu
# 2022-06-30 22:21:19 INFO: Loading: tokenize
# 2022-06-30 22:21:19 INFO: Loading: mwt
# 2022-06-30 22:21:19 INFO: Loading: pos
# 2022-06-30 22:21:19 INFO: Loading: lemma
# 2022-06-30 22:21:19 INFO: Loading: depparse
# 2022-06-30 22:21:19 INFO: Loading: ner
# 2022-06-30 22:21:20 INFO: Done loading processors!
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2d432a9d3ab34939a259c6879351f53f-0" class="displacy" width="290" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">مابعد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">في</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">أراك</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d432a9d3ab34939a259c6879351f53f-0-0" stroke-width="2px" d="M62,82.0 62,55.33333333333333 210.0,55.33333333333333 210.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d432a9d3ab34939a259c6879351f53f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,84.0 L58,76.0 66,76.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d432a9d3ab34939a259c6879351f53f-0-1" stroke-width="2px" d="M62,82.0 62,68.66666666666667 127.0,68.66666666666667 127.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d432a9d3ab34939a259c6879351f53f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M127.0,84.0 L131.0,76.0 123.0,76.0" fill="currentColor"/>
# </g>
# </svg></span>
# 2022-06-30 22:21:21 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …

# %%
from stanza.models.common.constant import is_right_to_left
import spacy
from spacy import displacy
from spacy.tokens import Doc
from stanza.utils import conll


def conll_to_visual(conll_file, pipeline, sent_count):
    """
    Takes in a conll file and visualizes it by converting the conll file to a Stanza Document object
    and visualizing it with the visualize_doc method. Input should be a proper conll file. The pipeline
    for the conll file to be processed in must be provided as well.
    """
    # convert conll file to doc
    doc = conll.CoNLL.conll2doc(conll_file)
    # visualize doc object for given number of sentences
    visualization_options = {"compact": True, "bg": "#09a3d5", "color": "white", "distance": 80,
                             "font": "Source Sans Pro"}
    nlp = spacy.load("en_core_web_sm")  # Must install the latest version of spaCy's en_core_web_sm before running
    sentences_to_visualize = []

    for i in range(sent_count):
        sentence = doc.sentences[i]
        words, lemmas, heads, deps, tags = [], [], [], [], []
        if is_right_to_left(pipeline):  # order of words displayed is reversed, dependency arcs remain intact
            sent_len = len(sentence.words)
            for word in reversed(sentence.words):
                words.append(word.text)
                lemmas.append(word.lemma)
                deps.append(word.deprel)
                tags.append(word.upos)
                if word.head == 0:  # spaCy head indexes are formatted differently than that of Stanza
                    heads.append(sent_len - word.id)
                else:
                    heads.append(sent_len - word.head)
        else:  # standard left to right rendering
            for word in sentence.words:
                words.append(word.text)
                lemmas.append(word.lemma)
                deps.append(word.deprel)
                tags.append(word.upos)
                if word.head == 0:
                    heads.append(word.id - 1)
                else:
                    heads.append(word.head - 1)
        document_result = Doc(nlp.vocab, words=words, lemmas=lemmas, heads=heads, deps=deps, pos=tags)
        sentences_to_visualize.append(document_result)

    for line in sentences_to_visualize:  # render all sentences through displaCy
        displacy.render(line, style="dep", options=visualization_options)
        


def main():
    file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\en_ewt-ud-test.conllu.txt"
    conll_to_visual(file, "en", 15)


main()
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="73b7011de53d47e1ab4738052edd2629-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73b7011de53d47e1ab4738052edd2629-0-0" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73b7011de53d47e1ab4738052edd2629-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73b7011de53d47e1ab4738052edd2629-0-1" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73b7011de53d47e1ab4738052edd2629-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73b7011de53d47e1ab4738052edd2629-0-2" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73b7011de53d47e1ab4738052edd2629-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,124.0 L294.0,116.0 286.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73b7011de53d47e1ab4738052edd2629-0-3" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73b7011de53d47e1ab4738052edd2629-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,124.0 L378,116.0 386,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73b7011de53d47e1ab4738052edd2629-0-4" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73b7011de53d47e1ab4738052edd2629-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,124.0 L451.0,116.0 443.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6aa29d77b38c494cb9be8fd9f6b780a3-0" class="displacy" width="1490" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">engine (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">e-mail )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">wares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">full -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">fledged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">system ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-0" stroke-width="2px" d="M142,322.0 142,295.3333333333333 272.0,295.3333333333333 272.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,324.0 L138,316.0 146,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-1" stroke-width="2px" d="M222,322.0 222,308.6666666666667 269.0,308.6666666666667 269.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,324.0 L218,316.0 226,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-2" stroke-width="2px" d="M62,322.0 62,282.0 275.0,282.0 275.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M275.0,324.0 L279.0,316.0 271.0,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-3" stroke-width="2px" d="M382,322.0 382,242.0 924.0,242.0 924.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,324.0 L378,316.0 386,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-4" stroke-width="2px" d="M462,322.0 462,255.33333333333331 921.0,255.33333333333331 921.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,324.0 L458,316.0 466,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6aa29d77b38c494cb9be8fd9f6b780a3-0-5" stroke-width="2px" d="M542,322.0 542,308.6666666666667 589.0,308.6666666666667 589.0,322.0" fill="none" stroke="curr
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="48ef45cdfcd44d749a2cfcd990587bb3-0" class="displacy" width="690" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">via</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Microsoft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Watch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Mary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Jo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Foley ]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-0" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,124.0 L58,116.0 66,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-1" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-2" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-3" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,124.0 L378,116.0 386,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-4" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,124.0 L451.0,116.0 443.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-5" stroke-width="2px" d="M462,122.0 462,108.66666666666667 524.0,108.66666666666667 524.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-48ef45cdfcd44d749a2cfcd990587bb3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="
116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ead1469a9ae419f89aa563295343b87-0-8" stroke-width="2px" d="M782,122.0 782,108.66666666666667 844.0,108.66666666666667
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4fd5ffc7af984983aca18601a73d6fd1-0" class="displacy" width="1010" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">pictures</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">shows</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">flag</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Fallujah .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-0" stroke-width="2px" d="M62,162.0 62,108.66666666666666 370.0,108.66666666666666 370.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,164.0 L58,156.0 66,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-1" stroke-width="2px" d="M142,162.0 142,135.33333333333334 284.0,135.33333333333334 284.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,164.0 L138,156.0 146,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-2" stroke-width="2px" d="M222,162.0 222,148.66666666666666 281.0,148.66666666666666 281.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,164.0 L218,156.0 226,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-3" stroke-width="2px" d="M62,162.0 62,122.0 287.0,122.0 287.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M287.0,164.0 L291.0,156.0 283.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-4" stroke-width="2px" d="M462,162.0 462,148.66666666666666 521.0,148.66666666666666 521.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,164.0 L458,156.0 466,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-5" stroke-width="2px" d="M382,162.0 382,135.33333333333334 524.0,135.33333333333334 524.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M524.0,164.0 L528.0,156.0 520.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-6" stroke-width="2px" d="M622,162.0 622,135.33333333333334 764.0,135.33333333333334 764.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj:pass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M622,164.0 L618,156.0 626,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4fd5ffc7af984983aca18601a73d6fd1-0-7" stroke-width="2px" d="M702,162.0 702,148.66666666666666 761.0,148.66666666666666 761.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4fd5ffc7af984983aca18601a73d6fd1-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux:pass</textPath>
#     <

# %%
from stanza.models.common.constant import is_right_to_left
import spacy
from spacy import displacy
from spacy.tokens import Doc
from stanza.utils import conll
from stanza.utils.visualization import document_to_viz as viz


def conll_to_visual(conll_file, pipeline, sent_count=10, display_all=False):
    """
    Takes in a conll file and visualizes it by converting the conll file to a Stanza Document object
    and visualizing it with the visualize_doc method. Input should be a proper conll file. The pipeline
    for the conll file to be processed in must be provided as well. Optionally, the sent_count argument
    can be tweaked to display a different amount of sentences. To display all of the sentences in a
    conll file, the display_all argument can optionally be set to True. BEWARE: setting this argument
    for a large conll file may result in too many renderings, resulting in a crash.
    """
    # convert conll file to doc
    doc = conll.CoNLL.conll2doc(conll_file)

    if display_all:
        viz.visualize_doc(conll.CoNLL.conll2doc(conll_file), pipeline)
    else:  # visualize a given number of sentences
        visualization_options = {"compact": True, "bg": "#09a3d5", "color": "white", "distance": 80,
                                 "font": "Source Sans Pro"}  # see spaCy visualization settings doc for more options
        nlp = spacy.load("en_core_web_sm")  # Must install the latest version of spaCy's en_core_web_sm before running
        sentences_to_visualize = []
    
        for i in range(sent_count):
            sentence = doc.sentences[i]
            print(sentence.text)
            words, lemmas, heads, deps, tags = [], [], [], [], []
            if is_right_to_left(pipeline):  # order of words displayed is reversed, dependency arcs remain intact
                sent_len = len(sentence.words)
                for word in reversed(sentence.words):
                    words.append(word.text)
                    lemmas.append(word.lemma)
                    deps.append(word.deprel)
                    tags.append(word.upos)
                    if word.head == 0:  # spaCy head indexes are formatted differently than that of Stanza
                        heads.append(sent_len - word.id)
                    else:
                        heads.append(sent_len - word.head)
            else:  # standard left to right rendering
                for word in sentence.words:
                    words.append(word.text)
                    lemmas.append(word.lemma)
                    deps.append(word.deprel)
                    tags.append(word.upos)
                    if word.head == 0:
                        heads.append(word.id - 1)
                    else:
                        heads.append(word.head - 1)
            document_result = Doc(nlp.vocab, words=words, lemmas=lemmas, heads=heads, deps=deps, pos=tags)
            sentences_to_visualize.append(document_result)
    
        for line in sentences_to_visualize:  # render all sentences through displaCy
            displacy.render(line, style="dep", options=visualization_options)


def main():
    file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\en_ewt-ud-test.conllu.txt"
    conll_to_visual(file, "en", sent_count=2)
    # conll_to_visual(file, "en")
    # conll_to_visual(file, "en", sent_count=20)
    # conll_to_visual(file, "en", display_all=True)
    jp_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ja_gsd-ud-test.conllu.txt"
    ud_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ur_udtb-ud-test.conllu.txt"
    ar_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ar_padt-ud-test.conllu.txt"
#     conll_to_visual(jp_file, "ja")
 #    conll_to_visual(ar_file, "ar")
    conll_to_visual(ud_file, "ur")


main()
# Out:
# What if Google Morphed Into GoogleOS?
# What if Google expanded on its search-engine (and now e-mail) wares into a full-fledged operating system?
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="16e8794035694b18aaf2204864bc114a-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-16e8794035694b18aaf2204864bc114a-0-0" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-16e8794035694b18aaf2204864bc114a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-16e8794035694b18aaf2204864bc114a-0-1" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-16e8794035694b18aaf2204864bc114a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-16e8794035694b18aaf2204864bc114a-0-2" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-16e8794035694b18aaf2204864bc114a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,124.0 L294.0,116.0 286.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-16e8794035694b18aaf2204864bc114a-0-3" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-16e8794035694b18aaf2204864bc114a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,124.0 L378,116.0 386,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-16e8794035694b18aaf2204864bc114a-0-4" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-16e8794035694b18aaf2204864bc114a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,124.0 L451.0,116.0 443.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ddd10e52808a499f99d8366e1d6331e2-0" class="displacy" width="1490" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">engine (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">e-mail )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">wares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">full -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">fledged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">system ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ddd10e52808a499f99d8366e1d6331e2-0-0" stroke-width="2px" d="M142,322.0 142,295.3333333333333 272.0,295.3333333333333 272.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ddd10e52808a499f99d8366e1d6331e2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,324.0 L138,316.0 146,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ddd10e52808a499f99d8366e1d6331e2-0-1" stroke-width="2px" d="M222,322.0 222,308.6666666666667 269.0,308.6666666666667 269.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ddd10e52808a499f99d8366e1d6331e2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7e12f913784644b994549dee6d99e7c8-0" class="displacy" width="2370" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">کیا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">روانہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">مکتوب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">کو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">کمشنر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">الیکشن</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">چیف</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">ہوئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">کرتے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">مطالبہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">کا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">تعیناتی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">فورسیس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">اضافی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">انتخابات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">ضمنی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">کڑپہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">نے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">نائیڈو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">بابو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">چندرا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">این</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">مسٹر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">تلگودیشم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">صدر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e12f913784644b994549dee6d99e7c8-0-0" stroke-width="2px" d="M62,242.0 62,228.66666666666666 115.0,228.66666666666666 115.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e12f913784644b994549dee6d99e7c8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</te
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2ace10083a5a41e7a8f3cef77c6322cf-0" class="displacy" width="3570" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">ہے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">خدشہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">کا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">جانے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">پھیلائے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">بدامنی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">سے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">جانب</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">عناصر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">غیرسماجی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">انتخابات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">ان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">کہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">کہا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">ہوئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">کرتے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">مطالبہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">کا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">کرنے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">تعینات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">فورس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">پولیس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">زائد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">لئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">بنانے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">شفاف</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">CCONJ</tspan>
# </text>
#
# <text
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7c3999114c0f46a291ad2981d6475aa9-0" class="displacy" width="3250" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">سکے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">جا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">بنایا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">یقینی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">کو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">انتخابات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">منصفانہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">آزادانہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">تاکہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">کریں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">اقدامات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">بنانے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">یقینی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">کو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">تعیناتی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">فورس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">علحدہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">علحدہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">اسمبلی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">حلقہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">ہر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">وہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">کہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">خواہش</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">سے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <t
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0e39cb57e0794912adeddbe744b13177-0" class="displacy" width="3410" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">ہیں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">رہے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">کر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">منصوبہ_بندی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">دھاندلیوں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">انتخابات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">عناصر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">گروہ_واری</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">کڑپہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">ضلع</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">کہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">کہا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">ہوئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">دیتے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">حوالہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">کا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">واقعات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">طرح</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">اس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">نے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">نائیڈو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">مسٹر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">بعد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">حملہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">ہوئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d1b07d985c9d4d0fb8d8a25c5b37cc12-0" class="displacy" width="2930" height="537.0" direction="ltr" style="max-width: none; height: 537.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">جائیں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">کئے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">انتظامات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">تھا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">کرتا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">عشق</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">سے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">کام</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">ایم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">متعلم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">صنم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">فروین</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">خاتون</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">سالہ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">24</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">جو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">ملازم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">خانگی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">کرشنا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">بھارت</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">ڈی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec140e20fe8343b485d83e38ddefc781-0-0" stroke-width="2px" d="M62,202.0 62,175.33333333333334 201.0,175.33333333333334 201.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec140e20fe8343b485d83e38ddefc781-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,204.0 L58,196.0 66,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec140e20fe8343b485d83e38ddefc781-0-1" stroke-width="2px" d="M142,202.0 142,188.66666666666666 198.0,188.66666666666666 198.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec140e20fe8343b485d83e38ddefc781-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,204.0 L138,196.0 146,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec140e20fe8343b485d83e38ddefc781-0-2" stroke-width="2px" d="M222,202.0 222,188.66666666666666 278.0,188.66666666666666 278.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec140e20fe8343b485d83e38ddefc781-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M278.0,204.0 L282.0,196.0 274.0,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec140e20fe8343b485d83e38ddefc781-0-3" stroke-width="2px" d="M382,202.0 382,188.66666666666666 438.0,188.66666666666666 438.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec140e20fe8343b485d83e38ddefc781-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,204.0 L378,196.0 386,196.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ec140e20fe8343b485d83e38ddefc781-0-4" stroke-width="2px" d="M222,202.0 222,175.33333333333334 441.0,175.33333333333334 441.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ec140e20fe8343b485d83e38ddefc781-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M441.0,204.0
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f6c1464c73914abeb2c1d4a5c3475e40-0" class="displacy" width="2210" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">۔</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">تھی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">مقرر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">شادی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">کو</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">مئی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">21</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">اور</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">تھا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">کیا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">اتفاق</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">سے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">شادی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">بعد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">کرنے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">منگنی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">مےں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">فبروری</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">سال</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">اس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">کی</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">ان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">خاندان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">ارکان</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">کے</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">دونوں</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f6c1464c73914abeb2c1d4a5c3475e40-0-0" stroke-width="2px" d="M62,282.0 62,215.33333333333331 764.0,215.33333333333331 764.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f6c1464c73914abeb2c1d4a5c3475e40-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,284.0 L58,276.0 66,276.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f6c1464c73914abeb2c1d4a5c3475e40-0-1" stroke-width="2px" d="M142,282.0 142,268.6666666666667 192.0,268.6666666666667 192.0,282.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f6c1464c73914abeb2c1d4a5c3475e40-0-1" class="displacy-label" start

# %%
from stanza.models.common.constant import is_right_to_left
import spacy
from spacy import displacy
from spacy.tokens import Doc
from stanza.utils import conll
from stanza.utils.visualization import document_to_viz as viz


def conll_to_visual(conll_file, pipeline, sent_count=10, display_all=False):
    """
    Takes in a conll file and visualizes it by converting the conll file to a Stanza Document object
    and visualizing it with the visualize_doc method. Input should be a proper conll file. The pipeline
    for the conll file to be processed in must be provided as well. Optionally, the sent_count argument
    can be tweaked to display a different amount of sentences. To display all of the sentences in a
    conll file, the display_all argument can optionally be set to True. BEWARE: setting this argument
    for a large conll file may result in too many renderings, resulting in a crash.
    """
    # convert conll file to doc
    doc = conll.CoNLL.conll2doc(conll_file)

    if display_all:
        viz.visualize_doc(conll.CoNLL.conll2doc(conll_file), pipeline)
    else:  # visualize a given number of sentences
        visualization_options = {"compact": True, "bg": "#09a3d5", "color": "white", "distance": 80,
                                 "font": "Source Sans Pro"}  # see spaCy visualization settings doc for more options
        nlp = spacy.load("en_core_web_sm")  # Must install the latest version of spaCy's en_core_web_sm before running
        sentences_to_visualize, rtl = [], is_right_to_left(pipeline)

        for i in range(sent_count):
            sentence = doc.sentences[i]
            words, lemmas, heads, deps, tags = [], [], [], [], []
            sentence_words = sentence.words
            if rtl:
                sentence_words = reversed(sentence.words)
                sent_len = len(sentence.words)
            for word in sentence_words:
                words.append(word.text)
                lemmas.append(word.lemma)
                deps.append(word.deprel)
                tags.append(word.upos)
                if rtl and word.head == 0:  # word heads are off-by-1 in spaCy doc inits compared to Stanza
                    heads.append(sent_len - word.id)
                elif rtl and word.head != 0:
                    heads.append(sent_len - word.head)
                elif not rtl and word.head == 0:
                    heads.append(word.id - 1)
                elif not rtl and word.head != 0:
                    heads.append(word.head - 1)
                    
            document_result = Doc(nlp.vocab, words=words, lemmas=lemmas, heads=heads, deps=deps, pos=tags)
            sentences_to_visualize.append(document_result)

        for line in sentences_to_visualize:  # render all sentences through displaCy
            displacy.render(line, style="dep", options=visualization_options)


def main():
    file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\en_ewt-ud-test.conllu.txt"
    conll_to_visual(file, "en", sent_count=2)
    # conll_to_visual(file, "en")
    # conll_to_visual(file, "en", sent_count=20)
    # conll_to_visual(file, "en", display_all=True)
    jp_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ja_gsd-ud-test.conllu.txt"
    # ud_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ur_udtb-ud-test.conllu.txt"
    ar_file = "C:\\Users\\Alex\\stanza\\stanza\\utils\\visualization\\ar_padt-ud-test.conllu.txt"
    conll_to_visual(jp_file, "ja")
    conll_to_visual(ar_file, "ar")
    # conll_to_visual(ud_file, "ur")


main()
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c60b09cdf66441fab43067e386a35abf-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Morphed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">GoogleOS ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c60b09cdf66441fab43067e386a35abf-0-0" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c60b09cdf66441fab43067e386a35abf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c60b09cdf66441fab43067e386a35abf-0-1" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c60b09cdf66441fab43067e386a35abf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c60b09cdf66441fab43067e386a35abf-0-2" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c60b09cdf66441fab43067e386a35abf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,124.0 L294.0,116.0 286.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c60b09cdf66441fab43067e386a35abf-0-3" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c60b09cdf66441fab43067e386a35abf-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,124.0 L378,116.0 386,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c60b09cdf66441fab43067e386a35abf-0-4" stroke-width="2px" d="M302,122.0 302,95.33333333333333 447.0,95.33333333333333 447.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c60b09cdf66441fab43067e386a35abf-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,124.0 L451.0,116.0 443.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ed66da7a6b9e43d88973406018ec340a-0" class="displacy" width="1490" height="457.0" direction="ltr" style="max-width: none; height: 457.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">expanded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">search -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">engine (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">e-mail )</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">wares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">full -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">fledged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="367.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">system ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-0" stroke-width="2px" d="M142,322.0 142,295.3333333333333 272.0,295.3333333333333 272.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed66da7a6b9e43d88973406018ec340a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,324.0 L138,316.0 146,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-1" stroke-width="2px" d="M222,322.0 222,308.6666666666667 269.0,308.6666666666667 269.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed66da7a6b9e43d88973406018ec340a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,324.0 L218,316.0 226,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-2" stroke-width="2px" d="M62,322.0 62,282.0 275.0,282.0 275.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed66da7a6b9e43d88973406018ec340a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M275.0,324.0 L279.0,316.0 271.0,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-3" stroke-width="2px" d="M382,322.0 382,242.0 924.0,242.0 924.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed66da7a6b9e43d88973406018ec340a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M382,324.0 L378,316.0 386,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-4" stroke-width="2px" d="M462,322.0 462,255.33333333333331 921.0,255.33333333333331 921.0,322.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed66da7a6b9e43d88973406018ec340a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,324.0 L458,316.0 466,316.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed66da7a6b9e43d88973406018ec340a-0-5" stroke-width="2px" d="M542,322.0 542,308.6666666666667 589.0,308.6666666666667 589.0,322.0" fill="none" stroke="curr
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3b0cd817ea514afda7175376ada9270e-0" class="displacy" width="2450" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50